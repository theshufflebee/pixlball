# %%
import sys
import os

# Add repo root to Python path
repo_root = os.path.abspath("..")  # parent folder of notebooks
sys.path.append(repo_root)

# Now import your modules
from src.config import *

# %%
import sys
sys.path.append("../pitch_nn_project")

from src.config import *
from src.model import TinyCNN_MultiTask

print("Config loaded:", GRID_H, GRID_W)
print("Model:", TinyCNN_MultiTask())
# Out:
# Config loaded: 12 8
# Model: TinyCNN_MultiTask(
#   (conv1): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc_shared): Linear(in_features=1536, out_features=32, bias=True)
#   (fc_event): Linear(in_features=32, out_features=3, bias=True)
#   (fc_goal1): Linear(in_features=32, out_features=16, bias=True)
#   (fc_goal2): Linear(in_features=16, out_features=2, bias=True)
# )
