# %%
import sys
import os

# Add repo root to Python path
repo_root = os.path.abspath("..")  # parent folder of notebooks
sys.path.append(repo_root)

import pandas as pd
from statsbombpy import sb

# %% [markdown]
# # Download Data

# %%
competition_ids = [72, 53, 53, 43, 55, 55]
season_ids = [107, 315, 106, 106, 282, 43]

def get_match_overview(competition_ids, season_ids, requires_360=False):
    """
    Returns a filtered overview of matches for multiple competition/season pairs.
    
    Parameters:
        competition_ids (int or list): ID(s) of the competition(s)
        season_ids (int or list): ID(s) of the season(s)
        requires_360 (bool): If True, only return matches with 360 data
    
    Returns:
        pd.DataFrame: Combined and filtered overview dataframe
    """
    # Convert single integers to lists to keep the logic unified
    if isinstance(competition_ids, int):
        competition_ids = [competition_ids]
    if isinstance(season_ids, int):
        season_ids = [season_ids]
        
    if len(competition_ids) != len(season_ids):
        raise ValueError("The number of competition_ids must match the number of season_ids.")

    all_matches = []

    # Loop through each pair
    for comp_id, seas_id in zip(competition_ids, season_ids):
        try:
            df = sb.matches(competition_id=comp_id, season_id=seas_id)
            all_matches.append(df)
        except Exception as e:
            print(f"Warning: Could not fetch matches for Comp {comp_id}, Season {seas_id}: {e}")

    if not all_matches:
        return pd.DataFrame()

    # Combine all fetched data
    overview_df = pd.concat(all_matches, ignore_index=True)
    
    # Track 360 availability
    overview_df['available_360'] = overview_df['match_status_360'].notna()

    # --- Apply filters ---
    if requires_360:
        before_count = len(overview_df)
        overview_df = overview_df[overview_df['available_360'] == True]
        print(f"Dropped {before_count - len(overview_df)} matches without 360 data")

    return overview_df.reset_index(drop=True)

# %%
full_overview_df = get_match_overview(competition_ids, season_ids, requires_360=True)
# Out:
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Dropped 0 matches without 360 data

# %%
import pandas as pd
from statsbombpy import sb

def download_sb_data(overview_df, download_360=True):
    """
    Download StatsBomb event and 360 data for a list of matches.

    Parameters:
        overview_df (pd.DataFrame): Filtered matches overview with 'match_id'
        download_360 (bool): If True, download SB360 frame data; else only event data

    Returns:
        events_data (list of pd.DataFrame): List of event DataFrames per match
        frames_360_data (list of pd.DataFrame): List of SB360 frame DataFrames per match
    """
    events_data = []
    frames_360_data = []

    for match_id in overview_df['match_id']:
        # --- Download event data ---
        try:
            event_df = sb.events(match_id=match_id)
            events_data.append(event_df)
            print(f"Downloaded events for match {match_id} ({len(event_df)} rows)")
        except Exception as e:
            print(f"Failed to download events for match {match_id}: {e}")
            continue

        # --- Download 360 data if requested ---
        if download_360:
            try:
                frame_df = sb.frames(match_id=match_id)
                if 'visible_area' in frame_df.columns:
                    frame_df = frame_df.drop(columns=['visible_area'])
                frames_360_data.append(frame_df)
                print(f"Downloaded 360 frames for match {match_id} ({len(frame_df)} rows)")
            except Exception as e:
                print(f"No 360 data for match {match_id}: {e}")

    return events_data, frames_360_data

# %%
data_events, data_360 = download_sb_data(full_overview_df, download_360=True)
# Out:
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3904629 (3159 rows)
# Downloaded 360 frames for match 3904629 (33814 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3906390 (3581 rows)
# Downloaded 360 frames for match 3906390 (41984 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3906389 (3342 rows)
# Downloaded 360 frames for match 3906389 (40543 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 
rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788771 (3692 rows)
# Downloaded 360 frames for match 3788771 (44733 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788772 (3443 rows)
# Downloaded 360 frames for match 3788772 (44833 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788768 (4085 rows)
# Downloaded 360 frames for match 3788768 (63732 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788767 (3587 rows)
# Downloaded 360 frames for match 3788767 (46620 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788753 (3806 rows)
# Downloaded 360 frames for match 3788753 (60195 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788765 (3780 rows)
# Downloaded 360 frames for match 3788765 (49046 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788763 (3612 rows)
# Downloaded 360 frames for match 3788763 (42861 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788759 (3366 rows)
# Downloaded 360 frames for match 3788759 (43049 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788758 (3338 rows)
# Downloaded 360 frames for match 3788758 (41664 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788757 (3978 rows)
# Downloaded 360 frames for match 3788757 (58924 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788745 (3366 rows)
# Downloaded 360 frames for match 3788745 (36288 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3795107 (3617 rows)
# Downloaded 360 frames for match 3795107 (45852 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3795221 (4691 rows)
# Downloaded 360 frames for match 3795221 (53495 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3794689 (3119 rows)
# Downloaded 360 frames for match 3794689 (43889 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788746 (3969 rows)
# Downloaded 360 frames for match 3788746 (56207 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3794691 (4570 rows)
# Downloaded 360 frames for match 3794691 (58859 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3794690 (3099 rows)
# Downloaded 360 frames for match 3794690 (34464 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788756 (3748 rows)
# Downloaded 360 frames for match 3788756 (49527 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788749 (3628 rows)
# Downloaded 360 frames for match 3788749 (57650 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788750 (3677 rows)
# Downloaded 360 frames for match 3788750 (53867 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788748 (3440 rows)
# Downloaded 360 frames for match 3788748 (42522 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788751 (4031 rows)
# Downloaded 360 frames for match 3788751 (50152 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788752 (3709 rows)
# Downloaded 360 frames for match 3788752 (41891 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788742 (3488 rows)
# Downloaded 360 frames for match 3788742 (52745 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788775 (3627 rows)
# Downloaded 360 frames for match 3788775 (50404 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788776 (2880 rows)
# Downloaded 360 frames for match 3788776 (41826 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788743 (3858 rows)
# Downloaded 360 frames for match 3788743 (59813 rows)
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Downloaded events for match 3788744 (2997 rows)
# Downloaded 360 frames for match 3788744 (35109 rows)

# %%
# Store Events Dataframe
df_events = pd.concat(data_events, ignore_index=True)
print("starting saving event")
df_events.to_parquet('events_data.parquet', engine="fastparquet")
print("done")
df_events = None

# Store 360 Dataframe
df_360 = pd.concat(data_360, ignore_index=True)
print("starting saving 360")
df_360.to_parquet('360_data.parquet', engine="fastparquet")
print("done")
df_360 = None
# Out:
# starting saving event

# %%
import pandas as pd
data_events = pd.read_parquet("events_data.parquet", engine="fastparquet")

# %%
data_360 = pd.read_parquet("360_data.parquet", engine="fastparquet")

# %%
data_360.head()

# %%
data_events.head()
# Out:
#   50_50 bad_behaviour_card ball_receipt_outcome  \
# 0  None               None                 None
# 1  None               None                 None
# 2  None               None                 None
# 3  None               None                 None
# 4  None               None                 None
#
#    ball_recovery_recovery_failure  block_deflection carry_end_location  \
# 0                             NaN               NaN               None
# 1                             NaN               NaN               None
# 2                             NaN               NaN               None
# 3                             NaN               NaN               None
# 4                             NaN               NaN               None
#
#    clearance_aerial_won clearance_body_part  clearance_head  \
# 0                   NaN                None             NaN
# 1                   NaN                None             NaN
# 2                   NaN                None             NaN
# 3                   NaN                None             NaN
# 4                   NaN                None             NaN
#
#    clearance_left_foot  ...  goalkeeper_punched_out  block_save_block  \
# 0                  NaN  ...                     NaN               NaN
# 1                  NaN  ...                     NaN               NaN
# 2                  NaN  ...                     NaN               NaN
# 3                  NaN  ...                     NaN               NaN
# 4                  NaN  ...                     NaN               NaN
#
#    goalkeeper_penalty_saved_to_post dribble_no_touch goalkeeper_success_out  \
# 0                               NaN              NaN                    NaN
# 1                               NaN              NaN                    NaN
# 2                               NaN              NaN                    NaN
# 3                               NaN              NaN                    NaN
# 4                               NaN              NaN                    NaN
#
#   shot_follows_dribble  player_off_permanent  shot_redirect  \
# 0                  NaN                   NaN            NaN
# 1                  NaN                   NaN            NaN
# 2                  NaN                   NaN            NaN
# 3                  NaN                   NaN            NaN
# 4                  NaN                   NaN            NaN
#
#   goalkeeper_lost_out half_start_late_video_start
# 0                 NaN                         NaN
# 1                 NaN                         NaN
# 2                 NaN                         NaN
# 3                 NaN                         NaN
# 4                 NaN                         NaN
#
# [5 rows x 118 columns]

# %%
df_single_360 = sb.frames(match_id=3788747 )
# Out:
# /opt/conda/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
df_single_360
# Out:
#                                          id  \
# 0      ac1dfe29-900f-4799-8686-77e4936d535c
# 1      ac1dfe29-900f-4799-8686-77e4936d535c
# 2      ac1dfe29-900f-4799-8686-77e4936d535c
# 3      ac1dfe29-900f-4799-8686-77e4936d535c
# 4      ac1dfe29-900f-4799-8686-77e4936d535c
# ...                                     ...
# 42326  b72c67bb-1298-4385-aa41-c0c1cb7bb61a
# 42327  b72c67bb-1298-4385-aa41-c0c1cb7bb61a
# 42328  b72c67bb-1298-4385-aa41-c0c1cb7bb61a
# 42329  b72c67bb-1298-4385-aa41-c0c1cb7bb61a
# 42330  b72c67bb-1298-4385-aa41-c0c1cb7bb61a
#
#                                             visible_area  match_id  teammate  \
# 0      [42.2212629813216, 75.816055646492, 17.4692396...   3788747      True
# 1      [42.2212629813216, 75.816055646492, 17.4692396...   3788747      True
# 2      [42.2212629813216, 75.816055646492, 17.4692396...   3788747      True
# 3      [42.2212629813216, 75.816055646492, 17.4692396...   3788747      True
# 4      [42.2212629813216, 75.816055646492, 17.4692396...   3788747      True
# ...                                                  ...       ...       ...
# 42326  [36.6446291840376, 67.702808723767, 9.98898879...   3788747      True
# 42327  [36.6446291840376, 67.702808723767, 9.98898879...   3788747      True
# 42328  [36.6446291840376, 67.702808723767, 9.98898879...   3788747     False
# 42329  [36.6446291840376, 67.702808723767, 9.98898879...   3788747     False
# 42330  [36.6446291840376, 67.702808723767, 9.98898879...   3788747     False
#
#        actor  keeper                                  location
# 0      False   False    [36.73167006417611, 37.82023157211278]
# 1      False   False   [39.45708464313395, 18.649257282647188]
# 2      False   False  [41.024079151214174, 50.901264415136446]
# 3      False   False    [48.95456894567844, 42.16460858078651]
# 4      False   False   [50.412174246176455, 34.91454139780974]
# ...      ...     ...                                       ...
# 42326   True   False    [53.29999923706055, 40.70000076293945]
# 42327  False   False   [54.83300766545733, 12.076671485237043]
# 42328  False   False     [58.39128540455111, 51.3798217106149]
# 42329  False   False   [58.51811479121618, 43.610564215923354]
# 42330  False   False  [59.187987396222724, 26.807799944433302]
#
# [42331 rows x 7 columns]
